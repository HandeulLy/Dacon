# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading https://files.pythonhosted.org/packages/a8/77/b504e43e21a2ba543a1ac4696718beb500cfa708af2fb57cb54ce299045c/shap-0.35.0.tar.gz (273kB)
#      |████████████████████████████████| 276kB 3.5MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from shap) (1.18.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from shap) (0.22.2.post1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from shap) (0.25.3)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.6/dist-packages (from shap) (4.38.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->shap) (0.14.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->shap) (1.12.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.35.0-cp36-cp36m-linux_x86_64.whl size=394115 sha256=a4b5761320c67355f3ebd07292cd502278aeed49d5f38ed761fa7ef470498522
#   Stored in directory: /root/.cache/pip/wheels/e7/f7/0f/b57055080cf8894906b3bd3616d2fc2bfd0b12d5161bcb24ac
# Successfully built shap
# Installing collected packages: shap
# Successfully installed shap-0.35.0

# %%
import pandas as pd
import numpy as np

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import gc

import shap

# %%
DEBUG = False

if DEBUG:
    NFOLDS = 2
    N_ESTIMATORS = 50
else:
    NFOLDS = 5
    N_ESTIMATORS = 2500

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train = train.loc[:, train.max() != train.min()]

# %%
train['Y18'].isnull().sum(), train['Y18'].notnull().sum()
train_first_30 = train[train['Y18'].isnull()]
train_first_30.shape
train_later_3 = train[train['Y18'].notnull()]
train_later_3.shape
# Out:
# (432, 57)

# %%
X_train = train_first_30.loc[:, 'X00':'X39']
X_train
# Out:
#        X00    X01  X02  X03  X04     X05  ...    X34    X35  X36   X37   X38  X39
# 0      9.7  988.8  1.2  0.6  0.0  1009.3  ...   0.00  256.4  0.0  77.2  62.6  0.0
# 1      9.3  988.9  1.7  1.9  0.0  1009.3  ...   0.00  215.4  0.0  77.3  63.5  0.0
# 2      9.4  989.0  1.1  2.3  0.0  1009.2  ...   0.00  235.2  0.0  77.3  63.9  0.0
# 3      9.4  988.9  1.5  0.7  0.0  1009.2  ...   0.00  214.0  0.0  77.5  64.5  0.0
# 4      9.2  988.9  0.8  1.7  0.0  1009.2  ...   0.00  174.9  0.0  78.0  65.0  0.0
# ...    ...    ...  ...  ...  ...     ...  ...    ...    ...  ...   ...   ...  ...
# 4315  19.5  987.8  1.7  0.4  0.0  1007.8  ...  16.68  272.9  0.0  82.3  74.3  0.0
# 4316  19.3  987.7  2.1  0.9  0.0  1007.8  ...  16.68  315.9  0.0  82.4  74.8  0.0
# 4317  19.5  987.8  0.9  1.3  0.0  1007.8  ...  16.68  343.3  0.0  82.8  75.4  0.0
# 4318  20.0  987.8  1.4  0.5  0.0  1007.8  ...  16.68  341.7  0.0  82.8  75.8  0.0
# 4319  20.1  987.8  1.2  1.2  0.0  1007.8  ...  16.68  326.4  0.0  83.5  76.9  0.0
#
# [4320 rows x 37 columns]

# %%
X_train = pd.concat([X_train, X_train], axis=0)
X_train = pd.concat([X_train, train_later_3.loc[:, 'X00':'X39']], axis=0)
X_train
# Out:
#        X00    X01  X02  X03  X04     X05  ...    X34    X35  X36   X37   X38  X39
# 0      9.7  988.8  1.2  0.6  0.0  1009.3  ...   0.00  256.4  0.0  77.2  62.6  0.0
# 1      9.3  988.9  1.7  1.9  0.0  1009.3  ...   0.00  215.4  0.0  77.3  63.5  0.0
# 2      9.4  989.0  1.1  2.3  0.0  1009.2  ...   0.00  235.2  0.0  77.3  63.9  0.0
# 3      9.4  988.9  1.5  0.7  0.0  1009.2  ...   0.00  214.0  0.0  77.5  64.5  0.0
# 4      9.2  988.9  0.8  1.7  0.0  1009.2  ...   0.00  174.9  0.0  78.0  65.0  0.0
# ...    ...    ...  ...  ...  ...     ...  ...    ...    ...  ...   ...   ...  ...
# 4747  19.9  987.6  0.9  0.8  0.0  1006.9  ...  22.16  218.6  0.0  82.3  58.6  0.5
# 4748  19.9  987.6  0.5  0.7  0.0  1006.8  ...  22.16  161.7  0.0  82.5  59.1  0.5
# 4749  19.7  987.7  0.9  0.6  0.0  1006.9  ...  22.16  254.2  0.0  83.0  58.9  0.5
# 4750  19.4  987.7  0.9  0.8  0.0  1006.9  ...  22.16  300.0  0.0  83.2  59.8  0.5
# 4751  19.1  987.6  1.0  0.3  0.0  1006.8  ...  22.16  157.5  0.0  84.0  59.5  0.5
#
# [9072 rows x 37 columns]

# %%
#표준화 함수 생성
def standardization(df):
    mean = np.mean(df)
    std = np.std(df)
    norm = (df - mean) / (std - 1e-07)
    return norm, mean, std

# %%
# 학습데이터 표준화
X_train_norm, mean, std = standardization(X_train)

# %%
y_train = train_first_30.loc[:, 'Y16']
y_train = pd.concat([y_train, y_train], axis=0)
y_train = pd.concat([y_train, train_later_3.loc[:, 'Y18']], axis=0)
y_train
# Out:
# 0        8.0
# 1        7.5
# 2        7.5
# 3        7.5
# 4        7.5
#         ...
# 4747    21.5
# 4748    21.5
# 4749    21.5
# 4750    21.5
# 4751    21.0
# Length: 9072, dtype: float64

# %%
X_test = test.loc[:, 'X00':'X39']

# 모든 값이 동일한 column 제거
X_test = X_test.loc[:, X_test.max() != X_test.min()]

# 테스트데이터 표준화
X_test_norm = (X_test - mean) / (std - 1e-07)

# %%
# ID로 시간 변수 생성
minute = pd.Series((X_train_norm.index%144).astype(int))
hour= pd.Series((X_train_norm.index%144/6).astype(int))

# 삼각함수를 이용한 시간변수 생성
min_in_day = 24*6
hour_in_day = 24

minute_sin = np.sin(np.pi*minute/min_in_day) 
minute_cos = np.cos(np.pi*minute/min_in_day)

hour_sin  = np.sin(np.pi*hour/hour_in_day)
hour_cos  = np.cos(np.pi*hour/hour_in_day)

# %%
X_train_norm['minute_sin'] = minute_sin
X_train_norm['minute_cos'] = minute_cos

X_train_norm['hour_sin'] = hour_sin
X_train_norm['hour_cos'] = hour_cos
X_train_norm
# Out:
#            X00       X01       X02  ...  minute_cos  hour_sin  hour_cos
# 0    -2.200858  0.021446 -0.302269  ...    1.000000  0.000000  1.000000
# 1    -2.285482  0.050911  0.160625  ...    0.999762  0.000000  1.000000
# 2    -2.264326  0.080376 -0.394848  ...    0.999048  0.000000  1.000000
# 3    -2.264326  0.050911 -0.024533  ...    0.997859  0.000000  1.000000
# 4    -2.306638  0.050911 -0.672584  ...    0.996195  0.000000  1.000000
# ...        ...       ...       ...  ...         ...       ...       ...
# 4747 -0.042946 -0.332135 -0.580005  ...   -0.994056  0.130526 -0.991445
# 4748 -0.042946 -0.332135 -0.950320  ...   -0.996195  0.130526 -0.991445
# 4749 -0.085258 -0.302670 -0.580005  ...   -0.997859  0.130526 -0.991445
# 4750 -0.148726 -0.302670 -0.580005  ...   -0.999048  0.130526 -0.991445
# 4751 -0.212194 -0.332135 -0.487426  ...   -0.999762  0.130526 -0.991445
#
# [9072 rows x 41 columns]

# %%
# ID로 시간 변수 생성
minute = pd.Series((test.id%144).astype(int))
hour= pd.Series((test.id%144/6).astype(int))

# 삼각함수를 이용한 시간변수 생성
min_in_day = 24*6
hour_in_day = 24

minute_sin = np.sin(np.pi*minute/min_in_day) 
minute_cos = np.cos(np.pi*minute/min_in_day)

hour_sin  = np.sin(np.pi*hour/hour_in_day)
hour_cos  = np.cos(np.pi*hour/hour_in_day)

# %%
X_test_norm['minute_sin'] = minute_sin
X_test_norm['minute_cos'] = minute_cos

X_test_norm['hour_sin'] = hour_sin
X_test_norm['hour_cos'] = hour_cos
X_test_norm
# Out:
#             X00       X01       X02  ...  minute_cos  hour_sin  hour_cos
# 0     -0.296818 -0.391065 -0.024533  ...    1.000000  0.000000  1.000000
# 1     -0.275662 -0.391065 -0.394848  ...    0.999762  0.000000  1.000000
# 2     -0.233350 -0.391065 -0.209690  ...    0.999048  0.000000  1.000000
# 3     -0.296818 -0.391065  0.716097  ...    0.997859  0.000000  1.000000
# 4     -0.360286 -0.391065 -0.394848  ...    0.996195  0.000000  1.000000
# ...         ...       ...       ...  ...         ...       ...       ...
# 11515  1.184102  1.317909  2.197357  ...   -0.994056  0.130526 -0.991445
# 11516  1.162946  1.317909  1.364149  ...   -0.996195  0.130526 -0.991445
# 11517  1.162946  1.317909  2.104778  ...   -0.997859  0.130526 -0.991445
# 11518  1.141790  1.317909  0.808676  ...   -0.999048  0.130526 -0.991445
# 11519  1.120634  1.317909  1.364149  ...   -0.999762  0.130526 -0.991445
#
# [11520 rows x 41 columns]

# %%
X_train_norm_Y18 = X_train_norm.iloc[4320+4320:, :]

y_train_Y18 = y_train[4320+4320:]

# %%
# 실제값과 예측값의 차이가 1보다 작은 건 무시하는 Custom MSE Metric
def mse_ignoring_diff_less_than_one(y_pred, y_true):

    diff = abs(y_true - y_pred)
    mask_less_than_one = np.array([0 if x < 1 else 1 for x in diff])

    y_pred = mask_less_than_one * y_pred
    y_true = mask_less_than_one *y_true
    
    score =  mean_squared_error(y_true, y_pred)
    
    return 'score', score, False

# %%
# Y15, Y16, Y18을 활용한 훈련데이터 세트 모델링

feature_importance = pd.DataFrame()
feature_importance['feature'] = X_train_norm.columns

folds = KFold(n_splits=NFOLDS, shuffle=True)
y_preds = np.zeros(X_test_norm.shape[0])

model = XGBRegressor(n_estimators=N_ESTIMATORS,
                       max_depth=3,
                       learning_rate=0.007,
                     boost_from_average=False,
                       subsample=1,
                     loss_function='rmse',
                     scale_pos_weight=10,
                     coal_sample_by_tree=0.75,
                     min_child_weight=4,
                     feval=mse_ignoring_diff_less_than_one,
                       random_state=47)

for fold_n, (train_index, valid_index) in enumerate(folds.split(X_train_norm, y_train)):
    print('Fold: ', fold_n+1)
    X_train_fold, X_valid_fold = X_train_norm.iloc[train_index], X_train_norm.iloc[valid_index]
    y_train_fold, y_valid_fold = y_train.iloc[train_index], y_train.iloc[valid_index]
    
    evals = [(X_train_fold, y_train_fold), (X_valid_fold,  y_valid_fold)]
    model.fit(X_train_fold, 
              y_train_fold, 
              eval_set=evals,
              eval_metric='mae',
              verbose=100,
              early_stopping_rounds=50
             )
    
    shap_values = shap.TreeExplainer(model).shap_values(X_train_fold)
    fold_importance = pd.DataFrame()
    fold_importance['feature'] = X_train_norm.columns
    fold_importance['shap_values'] = abs(np.array(shap_values)[:, :].mean(0))
    fold_importance['feat_importance'] = model.feature_importances_
    feature_importance = pd.concat([feature_importance, fold_importance], sort=False)
        
    y_preds += model.predict(X_test_norm) / NFOLDS
    
    del X_train_fold, X_valid_fold, y_train_fold, y_valid_fold
    gc.collect()

feature_importance = feature_importance.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
# Out:
# Fold:  1
# [12:54:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:22.4318	validation_1-mae:22.7095
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# Series.base is deprecated and will be removed in a future version
# [100]	validation_0-mae:11.121	validation_1-mae:11.2527
# [200]	validation_0-mae:5.52449	validation_1-mae:5.5872
# [300]	validation_0-mae:2.77996	validation_1-mae:2.81837
# [400]	validation_0-mae:1.55589	validation_1-mae:1.59771
# [500]	validation_0-mae:1.09725	validation_1-mae:1.14729
# [600]	validation_0-mae:0.940957	validation_1-mae:0.995321
# [700]	validation_0-mae:0.877701	validation_1-mae:0.932122
# [800]	validation_0-mae:0.845329	validation_1-mae:0.900706
# [900]	validation_0-mae:0.823335	validation_1-mae:0.878732
# [1000]	validation_0-mae:0.80752	validation_1-mae:0.864561
# [1100]	validation_0-mae:0.793807	validation_1-mae:0.852995
# [1200]	validation_0-mae:0.780038	validation_1-mae:0.841309
# [1300]	validation_0-mae:0.76736	validation_1-mae:0.830843
# [1400]	validation_0-mae:0.756156	validation_1-mae:0.82143
# [1500]	validation_0-mae:0.744725	validation_1-mae:0.811104
# [1600]	validation_0-mae:0.733194	validation_1-mae:0.801171
# [1700]	validation_0-mae:0.723274	validation_1-mae:0.791907
# [1800]	validation_0-mae:0.714632	validation_1-mae:0.783995
# [1900]	validation_0-mae:0.706683	validation_1-mae:0.776868
# [2000]	validation_0-mae:0.696503	validation_1-mae:0.767586
# [2100]	validation_0-mae:0.687432	validation_1-mae:0.758758
# [2200]	validation_0-mae:0.678329	validation_1-mae:0.749886
# [2300]	validation_0-mae:0.668315	validation_1-mae:0.740595
# [2400]	validation_0-mae:0.660749	validation_1-mae:0.734355
# [2499]	validation_0-mae:0.652896	validation_1-mae:0.72782
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Fold:  2
# [12:55:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:22.4651	validation_1-mae:22.581
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# [100]	validation_0-mae:11.1369	validation_1-mae:11.2256
# [200]	validation_0-mae:5.53373	validation_1-mae:5.59974
# [300]	validation_0-mae:2.7872	validation_1-mae:2.85022
# [400]	validation_0-mae:1.55999	validation_1-mae:1.60311
# [500]	validation_0-mae:1.1005	validation_1-mae:1.12813
# [600]	validation_0-mae:0.942643	validation_1-mae:0.965434
# [700]	validation_0-mae:0.878469	validation_1-mae:0.903311
# [800]	validation_0-mae:0.846248	validation_1-mae:0.876486
# [900]	validation_0-mae:0.826195	validation_1-mae:0.860623
# [1000]	validation_0-mae:0.809148	validation_1-mae:0.846147
# [1100]	validation_0-mae:0.794076	validation_1-mae:0.833131
# [1200]	validation_0-mae:0.783056	validation_1-mae:0.823021
# [1300]	validation_0-mae:0.770178	validation_1-mae:0.811593
# [1400]	validation_0-mae:0.757262	validation_1-mae:0.800487
# [1500]	validation_0-mae:0.745863	validation_1-mae:0.791155
# [1600]	validation_0-mae:0.735072	validation_1-mae:0.782601
# [1700]	validation_0-mae:0.724293	validation_1-mae:0.774023
# [1800]	validation_0-mae:0.714623	validation_1-mae:0.76641
# [1900]	validation_0-mae:0.705852	validation_1-mae:0.75962
# [2000]	validation_0-mae:0.698049	validation_1-mae:0.753464
# [2100]	validation_0-mae:0.690687	validation_1-mae:0.747684
# [2200]	validation_0-mae:0.681182	validation_1-mae:0.739568
# [2300]	validation_0-mae:0.67237	validation_1-mae:0.732862
# [2400]	validation_0-mae:0.662918	validation_1-mae:0.724793
# [2499]	validation_0-mae:0.652956	validation_1-mae:0.716133
# Fold:  3
# [12:56:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:22.4987	validation_1-mae:22.4431
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# [100]	validation_0-mae:11.154	validation_1-mae:11.1009
# [200]	validation_0-mae:5.54166	validation_1-mae:5.49755
# [300]	validation_0-mae:2.79087	validation_1-mae:2.7486
# [400]	validation_0-mae:1.55784	validation_1-mae:1.54611
# [500]	validation_0-mae:1.09495	validation_1-mae:1.11305
# [600]	validation_0-mae:0.94094	validation_1-mae:0.969575
# [700]	validation_0-mae:0.876974	validation_1-mae:0.90963
# [800]	validation_0-mae:0.846767	validation_1-mae:0.879793
# [900]	validation_0-mae:0.82772	validation_1-mae:0.861985
# [1000]	validation_0-mae:0.812964	validation_1-mae:0.847286
# [1100]	validation_0-mae:0.79923	validation_1-mae:0.834345
# [1200]	validation_0-mae:0.787377	validation_1-mae:0.822885
# [1300]	validation_0-mae:0.77608	validation_1-mae:0.812066
# [1400]	validation_0-mae:0.764061	validation_1-mae:0.801211
# [1500]	validation_0-mae:0.753012	validation_1-mae:0.790271
# [1600]	validation_0-mae:0.741423	validation_1-mae:0.779884
# [1700]	validation_0-mae:0.729835	validation_1-mae:0.770265
# [1800]	validation_0-mae:0.719279	validation_1-mae:0.761087
# [1900]	validation_0-mae:0.709838	validation_1-mae:0.752882
# [2000]	validation_0-mae:0.7004	validation_1-mae:0.744868
# [2100]	validation_0-mae:0.691866	validation_1-mae:0.737574
# [2200]	validation_0-mae:0.683329	validation_1-mae:0.730523
# [2300]	validation_0-mae:0.675014	validation_1-mae:0.72379
# [2400]	validation_0-mae:0.667335	validation_1-mae:0.717208
# [2499]	validation_0-mae:0.65904	validation_1-mae:0.70999
# Fold:  4
# [12:57:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:22.5738	validation_1-mae:22.142
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# [100]	validation_0-mae:11.1911	validation_1-mae:10.9712
# [200]	validation_0-mae:5.55968	validation_1-mae:5.44305
# [300]	validation_0-mae:2.80237	validation_1-mae:2.74077
# [400]	validation_0-mae:1.56503	validation_1-mae:1.53153
# [500]	validation_0-mae:1.10159	validation_1-mae:1.09615
# [600]	validation_0-mae:0.946107	validation_1-mae:0.956705
# [700]	validation_0-mae:0.882528	validation_1-mae:0.903608
# [800]	validation_0-mae:0.849453	validation_1-mae:0.877337
# [900]	validation_0-mae:0.83083	validation_1-mae:0.861869
# [1000]	validation_0-mae:0.8157	validation_1-mae:0.848102
# [1100]	validation_0-mae:0.80294	validation_1-mae:0.836067
# [1200]	validation_0-mae:0.787599	validation_1-mae:0.821072
# [1300]	validation_0-mae:0.777604	validation_1-mae:0.811933
# [1400]	validation_0-mae:0.768168	validation_1-mae:0.803709
# [1500]	validation_0-mae:0.758862	validation_1-mae:0.795682
# [1600]	validation_0-mae:0.749711	validation_1-mae:0.787831
# [1700]	validation_0-mae:0.740465	validation_1-mae:0.780131
# [1800]	validation_0-mae:0.730874	validation_1-mae:0.772135
# [1900]	validation_0-mae:0.721977	validation_1-mae:0.764148
# [2000]	validation_0-mae:0.712737	validation_1-mae:0.756177
# [2100]	validation_0-mae:0.703181	validation_1-mae:0.747589
# [2200]	validation_0-mae:0.694209	validation_1-mae:0.739871
# [2300]	validation_0-mae:0.684891	validation_1-mae:0.731882
# [2400]	validation_0-mae:0.676133	validation_1-mae:0.723821
# [2499]	validation_0-mae:0.666766	validation_1-mae:0.715015
# Fold:  5
# [12:58:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:22.4693	validation_1-mae:22.5626
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# [100]	validation_0-mae:11.1392	validation_1-mae:11.1849
# [200]	validation_0-mae:5.53399	validation_1-mae:5.56608
# [300]	validation_0-mae:2.78726	validation_1-mae:2.8176
# [400]	validation_0-mae:1.55854	validation_1-mae:1.59693
# [500]	validation_0-mae:1.09724	validation_1-mae:1.14765
# [600]	validation_0-mae:0.940975	validation_1-mae:0.994072
# [700]	validation_0-mae:0.877648	validation_1-mae:0.932489
# [800]	validation_0-mae:0.846467	validation_1-mae:0.900922
# [900]	validation_0-mae:0.825701	validation_1-mae:0.880455
# [1000]	validation_0-mae:0.809806	validation_1-mae:0.864673
# [1100]	validation_0-mae:0.794792	validation_1-mae:0.850629
# [1200]	validation_0-mae:0.778091	validation_1-mae:0.835549
# [1300]	validation_0-mae:0.764487	validation_1-mae:0.823651
# [1400]	validation_0-mae:0.75311	validation_1-mae:0.813601
# [1500]	validation_0-mae:0.742823	validation_1-mae:0.804006
# [1600]	validation_0-mae:0.732763	validation_1-mae:0.79512
# [1700]	validation_0-mae:0.720188	validation_1-mae:0.78417
# [1800]	validation_0-mae:0.710053	validation_1-mae:0.77513
# [1900]	validation_0-mae:0.700598	validation_1-mae:0.767347
# [2000]	validation_0-mae:0.691295	validation_1-mae:0.759348
# [2100]	validation_0-mae:0.683008	validation_1-mae:0.752502
# [2200]	validation_0-mae:0.675631	validation_1-mae:0.746335
# [2300]	validation_0-mae:0.66665	validation_1-mae:0.738623
# [2400]	validation_0-mae:0.657305	validation_1-mae:0.73028
# [2499]	validation_0-mae:0.649748	validation_1-mae:0.723873

# %%
# Y18만 활용한 훈련데이터 세트 모델링

feature_importance_Y18 = pd.DataFrame()
feature_importance_Y18['feature'] = X_train_norm_Y18.columns

folds = KFold(n_splits=NFOLDS, shuffle=True)
y_preds_Y18 = np.zeros(X_test_norm.shape[0])

model_Y18 = LGBMRegressor(n_estimators=N_ESTIMATORS,
                       boosting_type='gbdt',
                       num_leaves=70,
                       max_depth=-1,
                       learning_rate=0.01,
                       objective='regression',
                       sub_sample=0.8,
                       colsample_bytree=0.8,
                       min_data_in_leaf=50,
                       bagging_seed=11,
                       # metric=mse_ignoring_diff_less_than_one,
                       verbosity=-1,
                       random_state=47)

for fold_n, (train_index, valid_index) in enumerate(folds.split(X_train_norm_Y18, y_train_Y18)):
    print('Fold: ', fold_n+1)
    X_train_fold, X_valid_fold = X_train_norm_Y18.iloc[train_index], X_train_norm_Y18.iloc[valid_index]
    y_train_fold, y_valid_fold = y_train_Y18.iloc[train_index], y_train_Y18.iloc[valid_index]
    
    evals = [(X_train_fold, y_train_fold), (X_valid_fold,  y_valid_fold)]
    model_Y18.fit(X_train_fold, 
              y_train_fold, 
              eval_metric=mse_ignoring_diff_less_than_one,
              eval_set=evals,
              early_stopping_rounds=50,
              verbose=100
             )
    
    shap_values = shap.TreeExplainer(model_Y18.booster_).shap_values(X_train_fold)
    fold_importance = pd.DataFrame()
    fold_importance['feature'] = X_train_norm_Y18.columns
    fold_importance['shap_values'] = abs(np.array(shap_values)[:, :].mean(0))
    fold_importance['feat_importance'] = model_Y18.feature_importances_
    feature_importance_Y18 = pd.concat([feature_importance_Y18, fold_importance], sort=False)
        
    y_preds_Y18 += model_Y18.predict(X_test_norm) / NFOLDS
    
    del X_train_fold, X_valid_fold, y_train_fold, y_valid_fold
    gc.collect()

feature_importance_Y18 = feature_importance_Y18.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
# Out:
# Fold:  1
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 7.35029	training's score: 7.28258	valid_1's l2: 7.80987	valid_1's score: 7.73032
# [200]	training's l2: 1.87515	training's score: 1.62317	valid_1's l2: 2.44658	valid_1's score: 2.24457
# [300]	training's l2: 0.86787	training's score: 0.694433	valid_1's l2: 1.49211	valid_1's score: 1.34453
# [400]	training's l2: 0.651333	training's score: 0.505478	valid_1's l2: 1.34263	valid_1's score: 1.18811
# [500]	training's l2: 0.535125	training's score: 0.391608	valid_1's l2: 1.25113	valid_1's score: 1.10721
# [600]	training's l2: 0.435584	training's score: 0.300137	valid_1's l2: 1.15842	valid_1's score: 1.02982
# [700]	training's l2: 0.373642	training's score: 0.242585	valid_1's l2: 1.08726	valid_1's score: 0.954319
# [800]	training's l2: 0.330366	training's score: 0.196728	valid_1's l2: 1.0412	valid_1's score: 0.903073
# [900]	training's l2: 0.296919	training's score: 0.170402	valid_1's l2: 1.00794	valid_1's score: 0.865669
# [1000]	training's l2: 0.271022	training's score: 0.143848	valid_1's l2: 0.988283	valid_1's score: 0.839899
# [1100]	training's l2: 0.249188	training's score: 0.123105	valid_1's l2: 0.970245	valid_1's score: 0.815598
# [1200]	training's l2: 0.230428	training's score: 0.104938	valid_1's l2: 0.947387	valid_1's score: 0.799799
# [1300]	training's l2: 0.213504	training's score: 0.0966556	valid_1's l2: 0.927857	valid_1's score: 0.774853
# [1400]	training's l2: 0.196336	training's score: 0.0804341	valid_1's l2: 0.900819	valid_1's score: 0.755558
# [1500]	training's l2: 0.183243	training's score: 0.0660434	valid_1's l2: 0.886239	valid_1's score: 0.743624
# [1600]	training's l2: 0.170793	training's score: 0.052912	valid_1's l2: 0.874615	valid_1's score: 0.723347
# [1700]	training's l2: 0.159979	training's score: 0.0412358	valid_1's l2: 0.864334	valid_1's score: 0.704785
# Early stopping, best iteration is:
# [1741]	training's l2: 0.155785	training's score: 0.0401758	valid_1's l2: 0.860708	valid_1's score: 0.702739
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Fold:  2
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 7.47074	training's score: 7.39557	valid_1's l2: 6.38904	valid_1's score: 6.33639
# [200]	training's l2: 1.86643	training's score: 1.62743	valid_1's l2: 1.68525	valid_1's score: 1.41353
# [300]	training's l2: 0.852425	training's score: 0.647484	valid_1's l2: 0.989837	valid_1's score: 0.782084
# Early stopping, best iteration is:
# [320]	training's l2: 0.783196	training's score: 0.570837	valid_1's l2: 0.95237	valid_1's score: 0.716097
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Fold:  3
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 7.53932	training's score: 7.47546	valid_1's l2: 7.0198	valid_1's score: 6.96978
# [200]	training's l2: 2.00793	training's score: 1.76973	valid_1's l2: 2.24618	valid_1's score: 2.03935
# [300]	training's l2: 0.962877	training's score: 0.787001	valid_1's l2: 1.23976	valid_1's score: 1.08194
# [400]	training's l2: 0.73106	training's score: 0.552249	valid_1's l2: 1.01653	valid_1's score: 0.863704
# [500]	training's l2: 0.590093	training's score: 0.432547	valid_1's l2: 0.908597	valid_1's score: 0.754552
# [600]	training's l2: 0.491557	training's score: 0.336119	valid_1's l2: 0.831094	valid_1's score: 0.700158
# [700]	training's l2: 0.41553	training's score: 0.264853	valid_1's l2: 0.754594	valid_1's score: 0.59532
# [800]	training's l2: 0.358515	training's score: 0.223699	valid_1's l2: 0.691218	valid_1's score: 0.531286
# [900]	training's l2: 0.317303	training's score: 0.179628	valid_1's l2: 0.664282	valid_1's score: 0.525704
# Early stopping, best iteration is:
# [891]	training's l2: 0.320473	training's score: 0.184485	valid_1's l2: 0.665266	valid_1's score: 0.51419
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Fold:  4
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 7.3495	training's score: 7.30383	valid_1's l2: 7.0683	valid_1's score: 7.01198
# [200]	training's l2: 1.95327	training's score: 1.72446	valid_1's l2: 1.97705	valid_1's score: 1.79013
# [300]	training's l2: 0.959673	training's score: 0.7829	valid_1's l2: 1.05176	valid_1's score: 0.879726
# [400]	training's l2: 0.737032	training's score: 0.600244	valid_1's l2: 0.855659	valid_1's score: 0.666087
# [500]	training's l2: 0.626927	training's score: 0.493094	valid_1's l2: 0.773271	valid_1's score: 0.592048
# [600]	training's l2: 0.504168	training's score: 0.373147	valid_1's l2: 0.686398	valid_1's score: 0.5331
# [700]	training's l2: 0.436129	training's score: 0.309232	valid_1's l2: 0.641335	valid_1's score: 0.477338
# [800]	training's l2: 0.387407	training's score: 0.271197	valid_1's l2: 0.61049	valid_1's score: 0.43836
# [900]	training's l2: 0.346894	training's score: 0.227434	valid_1's l2: 0.588411	valid_1's score: 0.4185
# [1000]	training's l2: 0.31463	training's score: 0.195304	valid_1's l2: 0.566607	valid_1's score: 0.401885
# [1100]	training's l2: 0.287846	training's score: 0.173146	valid_1's l2: 0.550057	valid_1's score: 0.36596
# [1200]	training's l2: 0.263389	training's score: 0.155827	valid_1's l2: 0.538018	valid_1's score: 0.358435
# Early stopping, best iteration is:
# [1226]	training's l2: 0.257921	training's score: 0.146688	valid_1's l2: 0.534052	valid_1's score: 0.355712
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Fold:  5
# Training until validation scores don't improve for 50 rounds.
# [100]	training's l2: 7.166	training's score: 7.09271	valid_1's l2: 10.0293	valid_1's score: 9.97071
# [200]	training's l2: 2.00261	training's score: 1.77089	valid_1's l2: 3.11288	valid_1's score: 2.93532
# [300]	training's l2: 1.0326	training's score: 0.856332	valid_1's l2: 1.64626	valid_1's score: 1.4727
# [400]	training's l2: 0.796864	training's score: 0.628354	valid_1's l2: 1.28401	valid_1's score: 1.13824
# [500]	training's l2: 0.645641	training's score: 0.484515	valid_1's l2: 1.06784	valid_1's score: 0.919988
# [600]	training's l2: 0.527041	training's score: 0.369132	valid_1's l2: 0.928057	valid_1's score: 0.763367
# [700]	training's l2: 0.446574	training's score: 0.298294	valid_1's l2: 0.844587	valid_1's score: 0.692334
# [800]	training's l2: 0.383699	training's score: 0.244353	valid_1's l2: 0.773338	valid_1's score: 0.632104
# [900]	training's l2: 0.338876	training's score: 0.201877	valid_1's l2: 0.719709	valid_1's score: 0.584921
# [1000]	training's l2: 0.304811	training's score: 0.167628	valid_1's l2: 0.685512	valid_1's score: 0.548872
# [1100]	training's l2: 0.278152	training's score: 0.136836	valid_1's l2: 0.657923	valid_1's score: 0.519176
# [1200]	training's l2: 0.255355	training's score: 0.112123	valid_1's l2: 0.635293	valid_1's score: 0.494692
# [1300]	training's l2: 0.235454	training's score: 0.101095	valid_1's l2: 0.61611	valid_1's score: 0.476169
# [1400]	training's l2: 0.21785	training's score: 0.0881433	valid_1's l2: 0.597988	valid_1's score: 0.43661
# [1500]	training's l2: 0.202636	training's score: 0.0817786	valid_1's l2: 0.582532	valid_1's score: 0.423162
# [1600]	training's l2: 0.188995	training's score: 0.0757469	valid_1's l2: 0.566055	valid_1's score: 0.43136
# Early stopping, best iteration is:
# [1608]	training's l2: 0.187963	training's score: 0.0753252	valid_1's l2: 0.565076	valid_1's score: 0.407143
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
# Y18만 활용한 훈련데이터 세트 모델링

feature_importance_Y18 = pd.DataFrame()
feature_importance_Y18['feature'] = X_train_norm_Y18.columns

folds = KFold(n_splits=NFOLDS, shuffle=True)
y_preds_Y18 = np.zeros(X_test_norm.shape[0])

model_Y18 = XGBRegressor(n_estimators=N_ESTIMATORS,
                       max_depth=3,
                       learning_rate=0.007,
                     boost_from_average=False,
                       subsample=1,
                     loss_function='rmse',
                     scale_pos_weight=10,
                     coal_sample_by_tree=0.75,
                     min_child_weight=4,
                     feval=mse_ignoring_diff_less_than_one,
                       random_state=47)

for fold_n, (train_index, valid_index) in enumerate(folds.split(X_train_norm_Y18, y_train_Y18)):
    print('Fold: ', fold_n+1)
    X_train_fold, X_valid_fold = X_train_norm_Y18.iloc[train_index], X_train_norm_Y18.iloc[valid_index]
    y_train_fold, y_valid_fold = y_train_Y18.iloc[train_index], y_train_Y18.iloc[valid_index]
    
    evals = [(X_train_fold, y_train_fold), (X_valid_fold,  y_valid_fold)]
    model_Y18.fit(X_train_fold, 
              y_train_fold, 
              eval_set=evals,
              eval_metric='mae',
              verbose=100,
              early_stopping_rounds=50
             )
    
    shap_values = shap.TreeExplainer(model).shap_values(X_train_fold)
    fold_importance = pd.DataFrame()
    fold_importance['feature'] = X_train_norm_Y18.columns
    fold_importance['shap_values'] = abs(np.array(shap_values)[:, :].mean(0))
    fold_importance['feat_importance'] = model_Y18.feature_importances_
    feature_importance_Y18 = pd.concat([feature_importance_Y18, fold_importance], sort=False)
        
    y_preds_Y18 += model_Y18.predict(X_test_norm) / NFOLDS
    
    del X_train_fold, X_valid_fold, y_train_fold, y_valid_fold
    gc.collect()
xgb_importance_Y18 = feature_importance_Y18.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
# Out:
# Fold:  1
# [13:09:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:26.3427	validation_1-mae:24.6739
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# Series.base is deprecated and will be removed in a future version
# [100]	validation_0-mae:13.1619	validation_1-mae:12.2843
# [200]	validation_0-mae:6.59336	validation_1-mae:6.15126
# [300]	validation_0-mae:3.3103	validation_1-mae:3.07175
# [400]	validation_0-mae:1.66879	validation_1-mae:1.55032
# [500]	validation_0-mae:0.856225	validation_1-mae:0.844916
# [600]	validation_0-mae:0.475035	validation_1-mae:0.563813
# [700]	validation_0-mae:0.328094	validation_1-mae:0.468963
# [800]	validation_0-mae:0.275183	validation_1-mae:0.431947
# [900]	validation_0-mae:0.252424	validation_1-mae:0.425447
# [1000]	validation_0-mae:0.238272	validation_1-mae:0.422244
# [1100]	validation_0-mae:0.227268	validation_1-mae:0.420808
# [1200]	validation_0-mae:0.217471	validation_1-mae:0.4191
# [1300]	validation_0-mae:0.207875	validation_1-mae:0.418064
# [1400]	validation_0-mae:0.198604	validation_1-mae:0.415583
# [1500]	validation_0-mae:0.189533	validation_1-mae:0.414453
# [1600]	validation_0-mae:0.18137	validation_1-mae:0.41437
# Stopping. Best iteration:
# [1573]	validation_0-mae:0.183562	validation_1-mae:0.414075
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Fold:  2
# [13:09:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:26.1814	validation_1-mae:25.3106
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# [100]	validation_0-mae:13.0801	validation_1-mae:12.5863
# [200]	validation_0-mae:6.55109	validation_1-mae:6.32093
# [300]	validation_0-mae:3.2888	validation_1-mae:3.17111
# [400]	validation_0-mae:1.65745	validation_1-mae:1.60433
# [500]	validation_0-mae:0.850047	validation_1-mae:0.861916
# [600]	validation_0-mae:0.487231	validation_1-mae:0.53837
# [700]	validation_0-mae:0.343923	validation_1-mae:0.414502
# [800]	validation_0-mae:0.282586	validation_1-mae:0.373419
# [900]	validation_0-mae:0.254576	validation_1-mae:0.354249
# [1000]	validation_0-mae:0.23674	validation_1-mae:0.344353
# [1100]	validation_0-mae:0.224282	validation_1-mae:0.342616
# [1200]	validation_0-mae:0.214269	validation_1-mae:0.341533
# [1300]	validation_0-mae:0.204776	validation_1-mae:0.340187
# [1400]	validation_0-mae:0.195612	validation_1-mae:0.338919
# [1500]	validation_0-mae:0.18784	validation_1-mae:0.338605
# [1600]	validation_0-mae:0.180251	validation_1-mae:0.338223
# [1700]	validation_0-mae:0.171743	validation_1-mae:0.337995
# [1800]	validation_0-mae:0.16401	validation_1-mae:0.337049
# [1900]	validation_0-mae:0.156992	validation_1-mae:0.336047
# Stopping. Best iteration:
# [1904]	validation_0-mae:0.156757	validation_1-mae:0.336012
#
# Fold:  3
# [13:09:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:25.8474	validation_1-mae:26.6473
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# [100]	validation_0-mae:12.9162	validation_1-mae:13.4101
# [200]	validation_0-mae:6.47	validation_1-mae:6.76335
# [300]	validation_0-mae:3.2485	validation_1-mae:3.42581
# [400]	validation_0-mae:1.63503	validation_1-mae:1.74938
# [500]	validation_0-mae:0.837033	validation_1-mae:0.950529
# [600]	validation_0-mae:0.476688	validation_1-mae:0.656588
# [700]	validation_0-mae:0.330633	validation_1-mae:0.557296
# [800]	validation_0-mae:0.274919	validation_1-mae:0.523088
# [900]	validation_0-mae:0.248303	validation_1-mae:0.507339
# [1000]	validation_0-mae:0.233651	validation_1-mae:0.501455
# [1100]	validation_0-mae:0.222455	validation_1-mae:0.495259
# [1200]	validation_0-mae:0.212913	validation_1-mae:0.490923
# [1300]	validation_0-mae:0.203465	validation_1-mae:0.489115
# [1400]	validation_0-mae:0.193959	validation_1-mae:0.484882
# [1500]	validation_0-mae:0.186264	validation_1-mae:0.479094
# [1600]	validation_0-mae:0.177493	validation_1-mae:0.474903
# [1700]	validation_0-mae:0.170591	validation_1-mae:0.46897
# [1800]	validation_0-mae:0.163103	validation_1-mae:0.464841
# [1900]	validation_0-mae:0.156218	validation_1-mae:0.460884
# [2000]	validation_0-mae:0.148679	validation_1-mae:0.458352
# [2100]	validation_0-mae:0.141649	validation_1-mae:0.45699
# [2200]	validation_0-mae:0.135395	validation_1-mae:0.454921
# [2300]	validation_0-mae:0.129726	validation_1-mae:0.452963
# [2400]	validation_0-mae:0.124867	validation_1-mae:0.451093
# [2499]	validation_0-mae:0.120369	validation_1-mae:0.449725
# Fold:  4
# [13:09:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:25.711	validation_1-mae:27.1993
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# [100]	validation_0-mae:12.8471	validation_1-mae:13.7662
# [200]	validation_0-mae:6.43645	validation_1-mae:7.01969
# [300]	validation_0-mae:3.23144	validation_1-mae:3.62167
# [400]	validation_0-mae:1.6268	validation_1-mae:1.9139
# [500]	validation_0-mae:0.830017	validation_1-mae:1.10641
# [600]	validation_0-mae:0.467944	validation_1-mae:0.741453
# [700]	validation_0-mae:0.326577	validation_1-mae:0.598094
# [800]	validation_0-mae:0.275061	validation_1-mae:0.541067
# [900]	validation_0-mae:0.25418	validation_1-mae:0.515418
# [1000]	validation_0-mae:0.240528	validation_1-mae:0.501916
# [1100]	validation_0-mae:0.226522	validation_1-mae:0.496347
# [1200]	validation_0-mae:0.215488	validation_1-mae:0.493256
# [1300]	validation_0-mae:0.205621	validation_1-mae:0.489762
# [1400]	validation_0-mae:0.196467	validation_1-mae:0.486914
# [1500]	validation_0-mae:0.188073	validation_1-mae:0.484042
# [1600]	validation_0-mae:0.180055	validation_1-mae:0.481482
# [1700]	validation_0-mae:0.17289	validation_1-mae:0.479274
# [1800]	validation_0-mae:0.164859	validation_1-mae:0.478486
# [1900]	validation_0-mae:0.157287	validation_1-mae:0.477341
# [2000]	validation_0-mae:0.150887	validation_1-mae:0.476804
# [2100]	validation_0-mae:0.145211	validation_1-mae:0.475923
# [2200]	validation_0-mae:0.138838	validation_1-mae:0.475104
# [2300]	validation_0-mae:0.132798	validation_1-mae:0.474245
# [2400]	validation_0-mae:0.127317	validation_1-mae:0.47395
# Stopping. Best iteration:
# [2357]	validation_0-mae:0.129661	validation_1-mae:0.473666
#
# Fold:  5
# [13:09:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:25.9508	validation_1-mae:26.2286
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# [100]	validation_0-mae:12.9677	validation_1-mae:13.0018
# [200]	validation_0-mae:6.49787	validation_1-mae:6.4285
# [300]	validation_0-mae:3.26	validation_1-mae:3.14726
# [400]	validation_0-mae:1.64463	validation_1-mae:1.50685
# [500]	validation_0-mae:0.846273	validation_1-mae:0.861382
# [600]	validation_0-mae:0.480812	validation_1-mae:0.666545
# [700]	validation_0-mae:0.329884	validation_1-mae:0.602297
# [800]	validation_0-mae:0.272673	validation_1-mae:0.580531
# [900]	validation_0-mae:0.248621	validation_1-mae:0.569869
# [1000]	validation_0-mae:0.234181	validation_1-mae:0.56339
# [1100]	validation_0-mae:0.223409	validation_1-mae:0.557042
# [1200]	validation_0-mae:0.214197	validation_1-mae:0.549876
# [1300]	validation_0-mae:0.205011	validation_1-mae:0.544642
# [1400]	validation_0-mae:0.19643	validation_1-mae:0.540084
# [1500]	validation_0-mae:0.188572	validation_1-mae:0.53818
# [1600]	validation_0-mae:0.1814	validation_1-mae:0.536537
# [1700]	validation_0-mae:0.174384	validation_1-mae:0.53376
# [1800]	validation_0-mae:0.167176	validation_1-mae:0.531173
# [1900]	validation_0-mae:0.160035	validation_1-mae:0.527534
# [2000]	validation_0-mae:0.152838	validation_1-mae:0.524406
# [2100]	validation_0-mae:0.146373	validation_1-mae:0.523302
# [2200]	validation_0-mae:0.140488	validation_1-mae:0.521879
# [2300]	validation_0-mae:0.134441	validation_1-mae:0.52041
# [2400]	validation_0-mae:0.129495	validation_1-mae:0.519312
# [2499]	validation_0-mae:0.123728	validation_1-mae:0.517658

# %%
ensembled_preds = 0.7 * y_preds + 0.3 * y_preds_Y18

submit = pd.DataFrame({'id':range(144*33, 144*113),
              'Y18':ensembled_preds})
submit.to_csv('xgb_result.csv', index = False)

# %%
y_preds
# Out:
# array([19.38420987, 19.45270252, 19.22534657, ..., 25.23366117,
#        24.74242973, 24.62841558])

# %%
feature_importance.sort_values(by=['feat_importance'], axis=0,ascending=False).head(12)
# Out:
#        feature  shap_values  feat_importance
# 4          X00     0.074556         0.268419
# 9          X32     0.039561         0.217917
# 2          X31     0.082703         0.157755
# 3          X12     0.077013         0.124028
# 1     hour_sin     0.097856         0.090599
# 0   minute_sin     0.134485         0.059391
# 7          X07     0.047870         0.028075
# 5          X37     0.054796         0.011453
# 12         X30     0.017612         0.007596
# 39         X39     0.000408         0.003727
# 8   minute_cos     0.043050         0.002859
# 29         X36     0.002095         0.002336

# %%
feature_importance_Y18.sort_values(by=['feat_importance'], axis=0,ascending=False).head(12)
# Out:
#        feature  shap_values  feat_importance
# 0   minute_sin     0.094806            502.6
# 3          X20     0.045751            370.4
# 5          X30     0.032781            321.8
# 11         X38     0.018446            306.8
# 7          X37     0.027134            291.2
# 2     hour_sin     0.071339            275.8
# 10         X28     0.019046            265.2
# 8   minute_cos     0.021015            237.4
# 15         X12     0.010304            218.8
# 4          X32     0.043028            201.2
# 1          X31     0.087945            199.8
# 9          X11     0.020758            175.4

# %%
xgb_importance_Y18.sort_values(by=['feat_importance'], axis=0,ascending=False).head(12)
# Out:
#        feature  shap_values  feat_importance
# 6     hour_sin     0.101902         0.316189
# 9          X12     0.061756         0.239774
# 11         X37     0.040174         0.194504
# 10         X30     0.059452         0.070944
# 19         X34     0.007591         0.025943
# 2          X31     0.661825         0.023315
# 1          X32     0.871539         0.022115
# 22         X08     0.004536         0.018023
# 4   minute_sin     0.251289         0.015405
# 28         X28     0.002707         0.014104
# 31         X38     0.002532         0.013797
# 0          X00     1.192406         0.009245
